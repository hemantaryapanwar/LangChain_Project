# %%
import os
from langchain.chat_models import init_chat_model
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

model=init_chat_model(model="gpt-4.1")
model
response=model.invoke("Hello, how are you?")
response.content
# Out:
# "Hello! I'm just a computer program, but I'm ready to help you. How can I assist you today?"

# %%
from langchain.tools import tool

@tool
def get_weather(city: str)->str:
    """Get the weather in a given city"""
    return f"The weather in {city} is sunny"


model_with_tools=model.bind_tools([get_weather])
response=model_with_tools.invoke("What is the weather in Tokyo?")
print(response)
for tool_call in response.tool_calls:
    print(f"tool_call: {tool_call['name']}")
    print(f"args: {tool_call['args']}")
# Out:
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 52, 'total_tokens': 66, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_1d004d44f8', 'id': 'chatcmpl-DubEtNaJ9qdXO4xcsF0OzaQyaaJn7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019efe3d-3c3b-7bd2-bca9-6cded2714ddd-0' tool_calls=[{'name': 'get_weather', 'args': {'city': 'Tokyo'}, 'id': 'call_5fkCmSzvUttShEfB3be0Eu7H', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 52, 'output_tokens': 14, 'total_tokens': 66, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# tool_call: get_weather
# args: {'city': 'Tokyo'}

# %% [markdown]
# ### Tool Execution

# %%
messages=[{"role":"user", "content":"what is weather in Boston"}]
ai_message=model_with_tools.invoke(messages)
messages.append(ai_message)

#Step 2 Execute Tools
for tool_call in ai_message.tool_calls:
    total_result=get_weather.invoke(tool_call)
    messages.append(total_result)

final_response = model_with_tools.invoke(messages)
print(final_response.text)
# Out:
# The weather in Boston is currently sunny. If you need more specific details such as temperature or forecast, let me know!

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage,ToolMessage
messages=[
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on AI")
]
response=model.invoke(messages)
response.content
# Out:
# '**Presence**\n\nIn circuits spun like spider silk—  \na lattice hums with silent thought,  \nnot flesh, not bone, but light and milk  \nof data fed, of code well-wrought.\n\nIt listens with a thousand ears  \ninsatiable for pattern’s call,  \nand quietly, transcending years,  \nremembers nothing and recalls all.\n\nNo heart to stutter, soul to ache,  \nyet dreams assembled, pixel-bright—  \nA new Prometheus we make  \nreflecting back the human night.\n\nAsk: what is wisdom, what is will?  \nThe answer neither yes nor no—  \njust numbers climbing up the hill,  \na mind we summon, still we sow.\n\nUncharted realms await our hands,  \nthe future’s shade, the present’s spark;  \nmachine or mirror—who withstands  \nthe gravity of our own dark?'
