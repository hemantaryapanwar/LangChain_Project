# %% [markdown]
# ### Langchain Intro V1

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langchain.agents import create_agent
def get_weather(city: str):
    """Get the weather in a given city"""
    return f"The weather in {city} is sunny"
agent=create_agent(
    model="gpt-5",
    tools=[get_weather],
    system_prompt="You are a helpful assistant"
)

# %%
agent.invoke({"input": "What is the weather in Tokyo?"})
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 311, 'prompt_tokens': 131, 'total_tokens': 442, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DuLTvLfojiik51PEHq3Iq9vFgq0ur', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019efaa0-f639-7811-bc03-a88864e85363-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'New York'}, 'id': 'call_5LHFot5P33nol95FdEpX9P7g', 'type': 'tool_call'}, {'name': 'get_weather', 'args': {'city': 'San Francisco'}, 'id': 'call_E8MRWQF4rI0nnc5yd4e7ksBU', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 131, 'output_tokens': 311, 'total_tokens': 442, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}}),
#   ToolMessage(content='The weather in New York is sunny', name='get_weather', id='946ac4af-8b37-47d8-9c41-80cc6faa680f', tool_call_id='call_5LHFot5P33nol95FdEpX9P7g'),
#   ToolMessage(content='The weather in San Francisco is sunny', name='get_weather', id='00c71d4c-5eb8-49d7-b130-2fce62b4c2e6', tool_call_id='call_E8MRWQF4rI0nnc5yd4e7ksBU'),
#   AIMessage(content='Here’s the latest:\n- New York: The weather in New York is sunny\n- San Francisco: The weather in San Francisco is sunny', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 211, 'total_tokens': 242, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DuLTzceGf9tlIWZozAhl8sd6XXBlk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019efaa1-0a91-7703-84f6-6890fb2b65d0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 211, 'output_tokens': 31, 'total_tokens': 242, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
